# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns; sns.set(style="ticks", color_codes=True)
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.impute import SimpleImputer


import os
print(os.listdir("data"))
# Out:
# ['features.csv', 'sampleSubmission.csv', 'stores.csv', 'test.csv', 'train.csv']

# %%
#import data
df = pd.read_csv("data/train.csv", names=['Store','Dept','Date','weeklySales','isHoliday'],sep=',', header=0)
features = pd.read_csv("data/features.csv", names = ['Store','Date','Temperature','Fuel_Price','MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5','CPI','Unemployment','IsHoliday'], sep=',', header=0)
#Drop isHoliday because it already exists in df
features = features.drop(columns=['IsHoliday'])
stores =pd.read_csv("data/stores.csv",names=['Store','Type','Size'], sep=',',header=0)

test = pd.read_csv("data/stores.csv")
sample_submission = pd.read_csv("data/sampleSubmission.csv")

#Join the features and store datasets to the training dataset
df = df.merge(stores, how='left').merge(features, how='left')


#Add data Features
df['Date'] = pd.to_datetime(df.Date)
test['Date'] = pd.to_datetime(df.Date)
df['Week'] = df.Date.dt.week
df['Year'] = df.Date.dt.year

df = df.sort_values(by=['Store','Date','Dept'])
df
# Out:
#         Store  Dept       Date  weeklySales  isHoliday Type    Size  \
# 0           1     1 2010-02-05     24924.50      False    A  151315
# 143         1     2 2010-02-05     50605.27      False    A  151315
# 286         1     3 2010-02-05     13740.12      False    A  151315
# 429         1     4 2010-02-05     39954.04      False    A  151315
# 572         1     5 2010-02-05     32229.38      False    A  151315
# ...       ...   ...        ...          ...        ...  ...     ...
# 421012     45    93 2012-10-26      2487.80      False    B  118221
# 421146     45    94 2012-10-26      5203.31      False    B  118221
# 421289     45    95 2012-10-26     56017.47      False    B  118221
# 421434     45    97 2012-10-26      6817.48      False    B  118221
# 421569     45    98 2012-10-26      1076.80      False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572        NaN        NaN        NaN        NaN
# 143           42.31       2.572        NaN        NaN        NaN        NaN
# 286           42.31       2.572        NaN        NaN        NaN        NaN
# 429           42.31       2.572        NaN        NaN        NaN        NaN
# 572           42.31       2.572        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 421012        58.85       3.882    4018.91      58.08      100.0     211.94
# 421146        58.85       3.882    4018.91      58.08      100.0     211.94
# 421289        58.85       3.882    4018.91      58.08      100.0     211.94
# 421434        58.85       3.882    4018.91      58.08      100.0     211.94
# 421569        58.85       3.882    4018.91      58.08      100.0     211.94
#
#         MarkDown5         CPI  Unemployment  Week  Year
# 0             NaN  211.096358         8.106     5  2010
# 143           NaN  211.096358         8.106     5  2010
# 286           NaN  211.096358         8.106     5  2010
# 429           NaN  211.096358         8.106     5  2010
# 572           NaN  211.096358         8.106     5  2010
# ...           ...         ...           ...   ...   ...
# 421012     858.33  192.308899         8.667    43  2012
# 421146     858.33  192.308899         8.667    43  2012
# 421289     858.33  192.308899         8.667    43  2012
# 421434     858.33  192.308899         8.667    43  2012
# 421569     858.33  192.308899         8.667    43  2012
#
# [421570 rows x 18 columns]

# %%
df.dtypes
# Out:
# Store                    int64
# Dept                     int64
# Date            datetime64[ns]
# weeklySales            float64
# isHoliday                 bool
# Type                    object
# Size                     int64
# Temperature            float64
# Fuel_Price             float64
# MarkDown1              float64
# MarkDown2              float64
# MarkDown3              float64
# MarkDown4              float64
# MarkDown5              float64
# CPI                    float64
# Unemployment           float64
# Week                     int64
# Year                     int64
# dtype: object

# %%
df.describe()
# Out:
#                Store           Dept    weeklySales           Size  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123  136727.915739
# std        12.785297      30.492054   22711.183519   60980.583328
# min         1.000000       1.000000   -4988.940000   34875.000000
# 25%        11.000000      18.000000    2079.650000   93638.000000
# 50%        22.000000      37.000000    7612.030000  140167.000000
# 75%        33.000000      74.000000   20205.852500  202505.000000
# max        45.000000      99.000000  693099.360000  219622.000000
#
#          Temperature     Fuel_Price      MarkDown1      MarkDown2  \
# count  421570.000000  421570.000000  150681.000000  111248.000000
# mean       60.090059       3.361027    7246.420196    3334.628621
# std        18.447931       0.458515    8291.221345    9475.357325
# min        -2.060000       2.472000       0.270000    -265.760000
# 25%        46.680000       2.933000    2240.270000      41.600000
# 50%        62.090000       3.452000    5347.450000     192.000000
# 75%        74.280000       3.738000    9210.900000    1926.940000
# max       100.140000       4.468000   88646.760000  104519.540000
#
#            MarkDown3      MarkDown4      MarkDown5            CPI  \
# count  137091.000000  134967.000000  151432.000000  421570.000000
# mean     1439.421384    3383.168256    4628.975079     171.201947
# std      9623.078290    6292.384031    5962.887455      39.159276
# min       -29.100000       0.220000     135.160000     126.064000
# 25%         5.080000     504.220000    1878.440000     132.022667
# 50%        24.600000    1481.310000    3359.450000     182.318780
# 75%       103.990000    3595.040000    5563.800000     212.416993
# max    141630.610000   67474.850000  108519.280000     227.232807
#
#         Unemployment
# count  421570.000000
# mean        7.960289
# std         1.863296
# min         3.879000
# 25%         6.891000
# 50%         7.866000
# 75%         8.572000
# max        14.313000

# %%
df.count()
# Out:
# Store           421570
# Dept            421570
# Date            421570
# weeklySales     421570
# isHoliday       421570
# Type            421570
# Size            421570
# Temperature     421570
# Fuel_Price      421570
# MarkDown1       150681
# MarkDown2       111248
# MarkDown3       137091
# MarkDown4       134967
# MarkDown5       151432
# CPI             421570
# Unemployment    421570
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# weeklySales          0
# isHoliday            0
# Type                 0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# dtype: int64

# %%
df.Type.value_counts()
# Out:
# A    215478
# B    163495
# C     42597
# Name: Type, dtype: int64

# %%
df.describe()
#May need to clean the data, Negative Sales shouldn't be possible unless they are considering returns as negatives
# Out:
#                Store           Dept    weeklySales           Size  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123  136727.915739
# std        12.785297      30.492054   22711.183519   60980.583328
# min         1.000000       1.000000   -4988.940000   34875.000000
# 25%        11.000000      18.000000    2079.650000   93638.000000
# 50%        22.000000      37.000000    7612.030000  140167.000000
# 75%        33.000000      74.000000   20205.852500  202505.000000
# max        45.000000      99.000000  693099.360000  219622.000000
#
#          Temperature     Fuel_Price      MarkDown1      MarkDown2  \
# count  421570.000000  421570.000000  150681.000000  111248.000000
# mean       60.090059       3.361027    7246.420196    3334.628621
# std        18.447931       0.458515    8291.221345    9475.357325
# min        -2.060000       2.472000       0.270000    -265.760000
# 25%        46.680000       2.933000    2240.270000      41.600000
# 50%        62.090000       3.452000    5347.450000     192.000000
# 75%        74.280000       3.738000    9210.900000    1926.940000
# max       100.140000       4.468000   88646.760000  104519.540000
#
#            MarkDown3      MarkDown4      MarkDown5            CPI  \
# count  137091.000000  134967.000000  151432.000000  421570.000000
# mean     1439.421384    3383.168256    4628.975079     171.201947
# std      9623.078290    6292.384031    5962.887455      39.159276
# min       -29.100000       0.220000     135.160000     126.064000
# 25%         5.080000     504.220000    1878.440000     132.022667
# 50%        24.600000    1481.310000    3359.450000     182.318780
# 75%       103.990000    3595.040000    5563.800000     212.416993
# max    141630.610000   67474.850000  108519.280000     227.232807
#
#         Unemployment
# count  421570.000000
# mean        7.960289
# std         1.863296
# min         3.879000
# 25%         6.891000
# 50%         7.866000
# 75%         8.572000
# max        14.313000

# %%
#there are a lot of Outliers throwing off the boxplot
ax = sns.boxplot(x="Type",y="weeklySales", data=df, showfliers = False)
df[df.weeklySales < 0].count()
#There aren't a lot of negative numbers, but those are at a department level.
#I could see a department have a negative week
# Out:
# Store           1285
# Dept            1285
# Date            1285
# weeklySales     1285
# isHoliday       1285
# Type            1285
# Size            1285
# Temperature     1285
# Fuel_Price      1285
# MarkDown1        481
# MarkDown2        330
# MarkDown3        424
# MarkDown4        432
# MarkDown5        484
# CPI             1285
# Unemployment    1285
# Week            1285
# Year            1285
# dtype: int64

# %%
df_store_date = df.groupby(['Store','Date'])['weeklySales'].agg('sum').reset_index()
df_store_date[df_store_date.weeklySales < 0].count()
# Out:
# Store          0
# Date           0
# weeklySales    0
# dtype: int64

# %% [markdown]
# Departments have negative weeks, but no store has a negative week, I'm ok with it

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True)
#Markdown1 and Markdown4 seem very correlated
#Size and Dept seem to be slightly correlated with Sales

# %%
plt.figure(figsize=(5,5))
sns.pairplot(df, vars=['weeklySales', 'Fuel_Price', 'Size', 'CPI', 'Dept', 'Temperature','Unemployment'])

# %% [markdown]
# Sales tend to go down when Fueld price increases
#
# The larger the store the more the sales
#
# Lower CPI, Lower sales
#
# More comfortable temperatues lead to more sales
#
# Lower unemployment more sales
#
# Basically all common sense stuff

# %%
df.isna().mean()*100
#So lots of the Markdown figures have missing info
# Out:
# Store            0.000000
# Dept             0.000000
# Date             0.000000
# weeklySales      0.000000
# isHoliday        0.000000
# Type             0.000000
# Size             0.000000
# Temperature      0.000000
# Fuel_Price       0.000000
# MarkDown1       64.257181
# MarkDown2       73.611025
# MarkDown3       67.480845
# MarkDown4       67.984676
# MarkDown5       64.079038
# CPI              0.000000
# Unemployment     0.000000
# dtype: float64

# %%
sns.pairplot(df.fillna(0), vars=['weeklySales', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5'])

# %%
sns.lineplot('Date','weeklySales', hue='Store', data=df)

# %%
#Let's save a copy of the original df.  There are so many missing values in these
#Columns they may not be valuable at all
#There is also the chance that a 0 markdown is more likely that anything else

original_df = df
original_df[['MarkDown1','MarkDown2','MarkDown3','MarkDown4', 'MarkDown5']] = original_df[['MarkDown1','MarkDown2','MarkDown3','MarkDown4', 'MarkDown5']].fillna(0)

imputer = SimpleImputer(strategy='median')
markdown_fixed = pd.DataFrame(imputer.fit_transform(df[['MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5']]), columns=['MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5'])
df=df.drop(['MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5'], axis=1)#drop unimputed columns
df.head(5)
df=pd.concat([df,markdown_fixed], axis=1)
df.head(5)
# Out:
#    Store  Dept        Date  weeklySales  isHoliday Type    Size  Temperature  \
# 0      1     1  2010-02-05     24924.50      False    A  151315        42.31
# 1      1     1  2010-02-12     46039.49       True    A  151315        38.51
# 2      1     1  2010-02-19     41595.55      False    A  151315        39.93
# 3      1     1  2010-02-26     19403.54      False    A  151315        46.63
# 4      1     1  2010-03-05     21827.90      False    A  151315        46.50
#
#    Fuel_Price         CPI  Unemployment  MarkDown1  MarkDown2  MarkDown3  \
# 0       2.572  211.096358         8.106    5347.45      192.0       24.6
# 1       2.548  211.242170         8.106    5347.45      192.0       24.6
# 2       2.514  211.289143         8.106    5347.45      192.0       24.6
# 3       2.561  211.319643         8.106    5347.45      192.0       24.6
# 4       2.625  211.350143         8.106    5347.45      192.0       24.6
#
#    MarkDown4  MarkDown5
# 0    1481.31    3359.45
# 1    1481.31    3359.45
# 2    1481.31    3359.45
# 3    1481.31    3359.45
# 4    1481.31    3359.45

# %%
# Out:
#    Store  Dept       Date  weeklySales  isHoliday Type    Size  Temperature  \
# 0      1     1 2010-02-05     24924.50      False    A  151315        42.31
# 1      1     1 2010-02-12     46039.49       True    A  151315        38.51
# 2      1     1 2010-02-19     41595.55      False    A  151315        39.93
# 3      1     1 2010-02-26     19403.54      False    A  151315        46.63
# 4      1     1 2010-03-05     21827.90      False    A  151315        46.50
#
#    Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0       2.572        NaN        NaN        NaN        NaN        NaN
# 1       2.548        NaN        NaN        NaN        NaN        NaN
# 2       2.514        NaN        NaN        NaN        NaN        NaN
# 3       2.561        NaN        NaN        NaN        NaN        NaN
# 4       2.625        NaN        NaN        NaN        NaN        NaN
#
#           CPI  Unemployment  Week  Year
# 0  211.096358         8.106     5  2010
# 1  211.242170         8.106     6  2010
# 2  211.289143         8.106     7  2010
# 3  211.319643         8.106     8  2010
# 4  211.350143         8.106     9  2010
